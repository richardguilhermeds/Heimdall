# %%
import os
import sys

p = r"G:\Meu Drive\Heimdall\heimdall"

if p not in sys.path:
    sys.path.insert(0, p)

path_env = os.environ.get("PATH", "")
if p not in path_env.split(os.pathsep):
    os.environ["PATH"] = p + os.pathsep + path_env

print("Added to sys.path and PATH:", p)

# %load_ext autoreload
# %autoreload 2
# Out:
# 2026-06-07 16:43:54.318 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-06-07 16:43:54.392 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# Added to sys.path and PATH: G:\Meu Drive\Heimdall\heimdall
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import *

relatorio_sfn = carregar_dados_sfn()
relatorio_sfn.head(3)
# Out:
# 2026-06-07 16:44:03.065 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-06-07 16:44:03.066 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#                Instituição  Conglomerado Prudencial  Conglomerado Financeiro  \
# 0     BANCO DO BRASIL S.A.                       BB                  49906.0
# 1  CAIXA ECONOMICA FEDERAL  CAIXA ECONÔMICA FEDERAL                  51626.0
# 2       ITAÚ UNIBANCO S.A.                     ITAU                  10069.0
#
#    Conglomerado Prudencial.1 TCB                TC  \
# 0                    80329.0  b1           Público
# 1                    80738.0  b1           Público
# 2                    80099.0  b1  Privado Nacional
#
#                                  TI     Cidade  UF     Data   Ativo Total  \
# ...

# %%
relatorio_sfn.groupby('TI', dropna=False).size()
# Out:
# TI
# 42.0                                                     8
# Agência de Fomento                                      64
# Associação de Poupança e Empréstimo                      4
# BNDES                                                    4
# Banco Comercial                                         55
# Banco Comercial Estrangeiro - Filial no país            16
# Banco Múltiplo                                         524
# Banco Múltiplo Cooperativo                               8
# Banco de Câmbio                                         20
# Banco de Desenvolvimento                                12
# Banco de Investimento                                   48
# Banco do Brasil - Banco Múltiplo                         4
# Caixa Econômica Federal                                  4
# Companhia Hipotecária                                   20
# Cooperativa de Crédito                                3105
# Instituições de Pagamento                              667
# ...
